# %% [markdown]
# <a href="https://colab.research.google.com/github/Kensuzuki95/CE888/blob/main/Lab-8/transfer_learning_FT_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task:
# In your Lab_8 folder, we have stored data under <data.zip> file. This is an image dataset with 4 classes (i.e. cats, dogs, humans, horses). Please implement both Feature Extractor and Fine-Tuning methods on data.zip. Please ignore use VG166 and you are free to use any other pre-trained models https://keras.io/api/applications/

# %% [markdown]
# # Load Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Unzip training data
from zipfile import ZipFile
file_name = "/content/drive/MyDrive/CE888 Data Science for Decision Making/data.zip"
with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('done')
# Out:
# done

# %%
import os
# Get all the paths
data_dir_list = os.listdir('/content/data')
#print(data_dir_list cats)
path, dirs, files = next(os.walk("/content/data/cats"))
file_count = len(files)
print(file_count)
#print(data_dir_list dogs)
path, dirs, files = next(os.walk("/content/data/dogs"))
file_count = len(files)
print(file_count)
#print(data_dir_list horses)
path, dirs, files = next(os.walk("/content/data/horses"))
file_count = len(files)
print(file_count)
#print(data_dir_list Humans)
path, dirs, files = next(os.walk("/content/data/Humans"))
file_count = len(files)
print(file_count)
# Out:
# 202
# 202
# 202
# 202

# %% [markdown]
# ## Make New Directory

# %%
base_dir = '/content/animal_data'
os.mkdir(base_dir)

# %%
train_dir = os.path.join(base_dir, 'train')
os.mkdir(train_dir)

validation_dir = os.path.join(base_dir, 'validation')
os.mkdir(validation_dir)

test_dir = os.path.join(base_dir, 'test')
os.mkdir(test_dir)

# %%
import shutil
fnames = ['cat.{}.jpg'.format(i) for i in range(1, 101)]
for fname in fnames:
    src = os.path.join('/content/data/cats', fname)
    dst = os.path.join(train_dir, fname)
    #print(src,dst)
    shutil.copyfile(src, dst)
    
fnames = ['cat.{}.jpg'.format(i) for i in range(101, 152)]
for fname in fnames:
    src = os.path.join('/content/data/cats', fname)
    dst = os.path.join(validation_dir, fname)
    shutil.copyfile(src, dst)

fnames = ['cat.{}.jpg'.format(i) for i in range(152, 203)]
for fname in fnames:
    src = os.path.join('/content/data/cats', fname)
    dst = os.path.join(test_dir, fname)
    shutil.copyfile(src, dst)
    
fnames = ['dog.{}.jpg'.format(i) for i in range(1, 101)]
for fname in fnames:
    src = os.path.join('/content/data/dogs', fname)
    dst = os.path.join(train_dir, fname)
    #print(src,dst)
    shutil.copyfile(src, dst)
    
fnames = ['dog.{}.jpg'.format(i) for i in range(101, 152)]
for fname in fnames:
    src = os.path.join('/content/data/dogs', fname)
    dst = os.path.join(validation_dir, fname)
    shutil.copyfile(src, dst)

fnames = ['dog.{}.jpg'.format(i) for i in range(152, 203)]
for fname in fnames:
    src = os.path.join('/content/data/dogs', fname)
    dst = os.path.join(test_dir, fname)
    shutil.copyfile(src, dst)

fnames = ['horse-{}.jpg'.format(i) for i in range(1, 101)]
for fname in fnames:
    src = os.path.join('/content/data/horses', fname)
    dst = os.path.join(train_dir, fname)
    #print(src,dst)
    shutil.copyfile(src, dst)
    
fnames = ['horse-{}.jpg'.format(i) for i in range(101, 152)]
for fname in fnames:
    src = os.path.join('/content/data/horses', fname)
    dst = os.path.join(validation_dir, fname)
    shutil.copyfile(src, dst)

fnames = ['horse-{}.jpg'.format(i) for i in range(152, 203)]
for fname in fnames:
    src = os.path.join('/content/data/horses', fname)
    dst = os.path.join(test_dir, fname)
    shutil.copyfile(src, dst)

fnames = ['rider-{}.jpg'.format(i) for i in range(1, 101)]
for fname in fnames:
    src = os.path.join('/content/data/Humans', fname)
    dst = os.path.join(train_dir, fname)
    #print(src,dst)
    shutil.copyfile(src, dst)
    
fnames = ['rider-{}.jpg'.format(i) for i in range(101, 152)]
for fname in fnames:
    src = os.path.join('/content/data/Humans', fname)
    dst = os.path.join(validation_dir, fname)
    shutil.copyfile(src, dst)

fnames = ['rider-{}.jpg'.format(i) for i in range(152, 203)]
for fname in fnames:
    src = os.path.join('/content/data/Humans', fname)
    dst = os.path.join(test_dir, fname)
    shutil.copyfile(src, dst)

# %%
import numpy as np
from random import shuffle

IMG_SIZE = 224
LR = 1e-4

# %% [markdown]
# # Labeling the Data

# %%
def label_img(img):
    if 'dog' in img: return 0
    elif 'cat' in img: return 1
    elif 'horse' in img: return 2
    elif 'rider' in img: return 3

# %% [markdown]
# # Creating Training / Validation/ Test Datasets

# %%
import cv2
def createDataSplitSet(datapath):
    X=[]
    y=[]
    for img in os.listdir(datapath):
        label = label_img(img)
        # print(label)
        path = os.path.join(datapath, img)
        image = cv2.resize(cv2.imread(path), (IMG_SIZE, IMG_SIZE))
        image = cv2.normalize(image, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)

        X.append(np.array(image))
        y.append(label)
    return np.array(X), np.array(y)

# %%
train_X, train_y = createDataSplitSet(train_dir)
val_X, val_y = createDataSplitSet(validation_dir)
test_X, test_y = createDataSplitSet(test_dir)
print(train_X.shape)
print(val_X.shape)
print(test_X.shape)
# Out:
# (400, 224, 224, 3)
# (204, 224, 224, 3)
# (204, 224, 224, 3)

# %% [markdown]
# # Create Model using NASNetLarge

# %%
## Import NASNetLarge [One of the highest performing model in image recognition]
from tensorflow.keras.applications import NASNetLarge
from tensorflow.keras.layers import Dense, Input, Flatten
from tensorflow.keras import Model

img_input = Input(shape=(IMG_SIZE, IMG_SIZE, 3))

# %%
model = NASNetLarge(
    include_top=True,
    weights="imagenet",
    input_tensor=img_input,
    input_shape=None,
    pooling=None,
    classes=1000,
    #classifier_activation="softmax"
    )
model.summary()
# Out:
# Model: "NASNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# stem_conv1 (Conv2D)             (None, 111, 111, 96) 2592        input_4[0][0]
# __________________________________________________________________________________________________
# stem_bn1 (BatchNormalization)   (None, 111, 111, 96) 384         stem_conv1[0][0]
# __________________________________________________________________________________________________
# activation_260 (Activation)     (None, 111, 111, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_1 (Conv2D (None, 111, 111, 42) 4032        activation_260[0][0]
# __________________________________________________________________________________________________
# reduction_bn_1_stem_1 (BatchNor (None, 111, 111, 42) 168         reduction_conv_1_stem_1[0][0]
# __________________________________________________________________________________________________
# activation_261 (Activation)     (None, 111, 111, 42) 0           reduction_bn_1_stem_1[0][0]
# __________________________________________________________________________________________________
# activation_263 (Activation)     (None, 111, 111, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 115, 115, 42) 0           activation_261[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 117, 117, 96) 0           activation_263[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 56, 56, 42)   2814        separable_conv_1_pad_reduction_le
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 56, 56, 42)   8736        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 56, 56, 42)   168         separable_conv_1_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 56, 56, 42)   168         separable_conv_1_reduction_right1
# __________________________________________________________________________________________________
# activation_262 (Activation)     (None, 56, 56, 42)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# activation_264 (Activation)     (None, 56, 56, 42)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 56, 56, 42)   2814        activation_262[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 56, 56, 42)   3822        activation_264[0][0]
# __________________________________________________________________________________________________
# activation_265 (Activation)     (None, 111, 111, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 56, 56, 42)   168         separable_conv_2_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 56, 56, 42)   168         separable_conv_2_reduction_right1
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 117, 117, 96) 0           activation_265[0][0]
# __________________________________________________________________________________________________
# activation_267 (Activation)     (None, 111, 111, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_add_1_stem_1 (Add)    (None, 56, 56, 42)   0           separable_conv_2_bn_reduction_lef
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 56, 56, 42)   8736        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 115, 115, 96) 0           activation_267[0][0]
# __________________________________________________________________________________________________
# activation_269 (Activation)     (None, 56, 56, 42)   0           reduction_add_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 56, 56, 42)   168         separable_conv_1_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 56, 56, 42)   6432        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 56, 56, 42)   2142        activation_269[0][0]
# __________________________________________________________________________________________________
# activation_266 (Activation)     (None, 56, 56, 42)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 56, 56, 42)   168         separable_conv_1_reduction_right3
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 56, 56, 42)   168         separable_conv_1_reduction_left4_
# __________________________________________________________________________________________________
# reduction_pad_1_stem_1 (ZeroPad (None, 113, 113, 42) 0           reduction_bn_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 56, 56, 42)   3822        activation_266[0][0]
# __________________________________________________________________________________________________
# activation_268 (Activation)     (None, 56, 56, 42)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# activation_270 (Activation)     (None, 56, 56, 42)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# reduction_left2_stem_1 (MaxPool (None, 56, 56, 42)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 56, 56, 42)   168         separable_conv_2_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 56, 56, 42)   2814        activation_268[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 56, 56, 42)   2142        activation_270[0][0]
# __________________________________________________________________________________________________
# adjust_relu_1_stem_2 (Activatio (None, 111, 111, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_add_2_stem_1 (Add)    (None, 56, 56, 42)   0           reduction_left2_stem_1[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# reduction_left3_stem_1 (Average (None, 56, 56, 42)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 56, 56, 42)   168         separable_conv_2_reduction_right3
# __________________________________________________________________________________________________
# reduction_left4_stem_1 (Average (None, 56, 56, 42)   0           reduction_add_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 56, 56, 42)   168         separable_conv_2_reduction_left4_
# __________________________________________________________________________________________________
# reduction_right5_stem_1 (MaxPoo (None, 56, 56, 42)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 112, 112, 96) 0           adjust_relu_1_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add3_stem_1 (Add)     (None, 56, 56, 42)   0           reduction_left3_stem_1[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 56, 56, 42)   0           reduction_add_2_stem_1[0][0]
#                                                                  reduction_left4_stem_1[0][0]
# __________________________________________________________________________________________________
# reduction_add4_stem_1 (Add)     (None, 56, 56, 42)   0           separable_conv_2_bn_reduction_lef
#                                                                  reduction_right5_stem_1[0][0]
# __________________________________________________________________________________________________
# cropping2d_4 (Cropping2D)       (None, 111, 111, 96) 0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# reduction_concat_stem_1 (Concat (None, 56, 56, 168)  0           reduction_add_2_stem_1[0][0]
#                                                                  reduction_add3_stem_1[0][0]
#                                                                  add_4[0][0]
#                                                                  reduction_add4_stem_1[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_1_stem_2 (Avera (None, 56, 56, 96)   0           adjust_relu_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_2_stem_2 (Avera (None, 56, 56, 96)   0           cropping2d_4[0][0]
# __________________________________________________________________________________________________
# activation_271 (Activation)     (None, 56, 56, 168)  0           reduction_concat_stem_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_1_stem_2 (Conv2D)   (None, 56, 56, 42)   4032        adjust_avg_pool_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_conv_2_stem_2 (Conv2D)   (None, 56, 56, 42)   4032        adjust_avg_pool_2_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_2 (Conv2D (None, 56, 56, 84)   14112       activation_271[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 56, 56, 84)   0           adjust_conv_1_stem_2[0][0]
#                                                                  adjust_conv_2_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_bn_1_stem_2 (BatchNor (None, 56, 56, 84)   336         reduction_conv_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_bn_stem_2 (BatchNormaliz (None, 56, 56, 84)   336         concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_272 (Activation)     (None, 56, 56, 84)   0           reduction_bn_1_stem_2[0][0]
# __________________________________________________________________________________________________
# activation_274 (Activation)     (None, 56, 56, 84)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 59, 59, 84)   0           activation_272[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 61, 61, 84)   0           activation_274[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 28, 28, 84)   9156        separable_conv_1_pad_reduction_le
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 28, 28, 84)   11172       separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 28, 28, 84)   336         separable_conv_1_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 28, 28, 84)   336         separable_conv_1_reduction_right1
# __________________________________________________________________________________________________
# activation_273 (Activation)     (None, 28, 28, 84)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# activation_275 (Activation)     (None, 28, 28, 84)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 28, 28, 84)   9156        activation_273[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 28, 28, 84)   11172       activation_275[0][0]
# __________________________________________________________________________________________________
# activation_276 (Activation)     (None, 56, 56, 84)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 28, 28, 84)   336         separable_conv_2_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 28, 28, 84)   336         separable_conv_2_reduction_right1
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 61, 61, 84)   0           activation_276[0][0]
# __________________________________________________________________________________________________
# activation_278 (Activation)     (None, 56, 56, 84)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add_1_stem_2 (Add)    (None, 28, 28, 84)   0           separable_conv_2_bn_reduction_lef
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 28, 28, 84)   11172       separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 59, 59, 84)   0           activation_278[0][0]
# __________________________________________________________________________________________________
# activation_280 (Activation)     (None, 28, 28, 84)   0           reduction_add_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 28, 28, 84)   336         separable_conv_1_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 28, 28, 84)   9156        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 28, 28, 84)   7812        activation_280[0][0]
# __________________________________________________________________________________________________
# activation_277 (Activation)     (None, 28, 28, 84)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 28, 28, 84)   336         separable_conv_1_reduction_right3
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 28, 28, 84)   336         separable_conv_1_reduction_left4_
# __________________________________________________________________________________________________
# reduction_pad_1_stem_2 (ZeroPad (None, 57, 57, 84)   0           reduction_bn_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 28, 28, 84)   11172       activation_277[0][0]
# __________________________________________________________________________________________________
# activation_279 (Activation)     (None, 28, 28, 84)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# activation_281 (Activation)     (None, 28, 28, 84)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# reduction_left2_stem_2 (MaxPool (None, 28, 28, 84)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 28, 28, 84)   336         separable_conv_2_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 28, 28, 84)   9156        activation_279[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 28, 28, 84)   7812        activation_281[0][0]
# __________________________________________________________________________________________________
# adjust_relu_1_0 (Activation)    (None, 56, 56, 168)  0           reduction_concat_stem_1[0][0]
# __________________________________________________________________________________________________
# reduction_add_2_stem_2 (Add)    (None, 28, 28, 84)   0           reduction_left2_stem_2[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# reduction_left3_stem_2 (Average (None, 28, 28, 84)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 28, 28, 84)   336         separable_conv_2_reduction_right3
# __________________________________________________________________________________________________
# reduction_left4_stem_2 (Average (None, 28, 28, 84)   0           reduction_add_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 28, 28, 84)   336         separable_conv_2_reduction_left4_
# __________________________________________________________________________________________________
# reduction_right5_stem_2 (MaxPoo (None, 28, 28, 84)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 57, 57, 168)  0           adjust_relu_1_0[0][0]
# __________________________________________________________________________________________________
# reduction_add3_stem_2 (Add)     (None, 28, 28, 84)   0           reduction_left3_stem_2[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 28, 28, 84)   0           reduction_add_2_stem_2[0][0]
#                                                                  reduction_left4_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add4_stem_2 (Add)     (None, 28, 28, 84)   0           separable_conv_2_bn_reduction_lef
#                                                                  reduction_right5_stem_2[0][0]
# __________________________________________________________________________________________________
# cropping2d_5 (Cropping2D)       (None, 56, 56, 168)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# reduction_concat_stem_2 (Concat (None, 28, 28, 336)  0           reduction_add_2_stem_2[0][0]
#                                                                  reduction_add3_stem_2[0][0]
#                                                                  add_5[0][0]
#                                                                  reduction_add4_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_1_0 (AveragePoo (None, 28, 28, 168)  0           adjust_relu_1_0[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_2_0 (AveragePoo (None, 28, 28, 168)  0           cropping2d_5[0][0]
# __________________________________________________________________________________________________
# adjust_conv_1_0 (Conv2D)        (None, 28, 28, 84)   14112       adjust_avg_pool_1_0[0][0]
# __________________________________________________________________________________________________
# adjust_conv_2_0 (Conv2D)        (None, 28, 28, 84)   14112       adjust_avg_pool_2_0[0][0]
# __________________________________________________________________________________________________
# activation_282 (Activation)     (None, 28, 28, 336)  0           reduction_concat_stem_2[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 28, 28, 168)  0           adjust_conv_1_0[0][0]
#                                                                  adjust_conv_2_0[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_0 (Conv2D)        (None, 28, 28, 168)  56448       activation_282[0][0]
# __________________________________________________________________________________________________
# adjust_bn_0 (BatchNormalization (None, 28, 28, 168)  672         concatenate_5[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_0 (BatchNormalizati (None, 28, 28, 168)  672         normal_conv_1_0[0][0]
# __________________________________________________________________________________________________
# activation_283 (Activation)     (None, 28, 28, 168)  0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# activation_285 (Activation)     (None, 28, 28, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_287 (Activation)     (None, 28, 28, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_289 (Activation)     (None, 28, 28, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_291 (Activation)     (None, 28, 28, 168)  0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_0 (None, 28, 28, 168)  32424       activation_283[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 28, 28, 168)  29736       activation_285[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_0 (None, 28, 28, 168)  32424       activation_287[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 28, 28, 168)  29736       activation_289[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_0 (None, 28, 28, 168)  29736       activation_291[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 168)  672         separable_conv_1_normal_left1_0[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_1_normal_right1_0[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 168)  672         separable_conv_1_normal_left2_0[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_1_normal_right2_0[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 168)  672         separable_conv_1_normal_left5_0[0
# __________________________________________________________________________________________________
# activation_284 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_286 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_288 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_290 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_292 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_0 (None, 28, 28, 168)  32424       activation_284[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 28, 28, 168)  29736       activation_286[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_0 (None, 28, 28, 168)  32424       activation_288[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 28, 28, 168)  29736       activation_290[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_0 (None, 28, 28, 168)  29736       activation_292[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 168)  672         separable_conv_2_normal_left1_0[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_2_normal_right1_0[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 168)  672         separable_conv_2_normal_left2_0[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_2_normal_right2_0[
# __________________________________________________________________________________________________
# normal_left3_0 (AveragePooling2 (None, 28, 28, 168)  0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# normal_left4_0 (AveragePooling2 (None, 28, 28, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# normal_right4_0 (AveragePooling (None, 28, 28, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 168)  672         separable_conv_2_normal_left5_0[0
# __________________________________________________________________________________________________
# normal_add_1_0 (Add)            (None, 28, 28, 168)  0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_0 (Add)            (None, 28, 28, 168)  0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_0 (Add)            (None, 28, 28, 168)  0           normal_left3_0[0][0]
#                                                                  adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# normal_add_4_0 (Add)            (None, 28, 28, 168)  0           normal_left4_0[0][0]
#                                                                  normal_right4_0[0][0]
# __________________________________________________________________________________________________
# normal_add_5_0 (Add)            (None, 28, 28, 168)  0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# normal_concat_0 (Concatenate)   (None, 28, 28, 1008) 0           adjust_bn_0[0][0]
#                                                                  normal_add_1_0[0][0]
#                                                                  normal_add_2_0[0][0]
#                                                                  normal_add_3_0[0][0]
#                                                                  normal_add_4_0[0][0]
#                                                                  normal_add_5_0[0][0]
# __________________________________________________________________________________________________
# activation_293 (Activation)     (None, 28, 28, 336)  0           reduction_concat_stem_2[0][0]
# __________________________________________________________________________________________________
# activation_294 (Activation)     (None, 28, 28, 1008) 0           normal_concat_0[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_1 (Conv2 (None, 28, 28, 168)  56448       activation_293[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_1 (Conv2D)        (None, 28, 28, 168)  169344      activation_294[0][0]
# __________________________________________________________________________________________________
# adjust_bn_1 (BatchNormalization (None, 28, 28, 168)  672         adjust_conv_projection_1[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_1 (BatchNormalizati (None, 28, 28, 168)  672         normal_conv_1_1[0][0]
# __________________________________________________________________________________________________
# activation_295 (Activation)     (None, 28, 28, 168)  0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# activation_297 (Activation)     (None, 28, 28, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_299 (Activation)     (None, 28, 28, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_301 (Activation)     (None, 28, 28, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_303 (Activation)     (None, 28, 28, 168)  0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_1 (None, 28, 28, 168)  32424       activation_295[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 28, 28, 168)  29736       activation_297[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_1 (None, 28, 28, 168)  32424       activation_299[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 28, 28, 168)  29736       activation_301[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_1 (None, 28, 28, 168)  29736       activation_303[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 168)  672         separable_conv_1_normal_left1_1[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_1_normal_right1_1[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 168)  672         separable_conv_1_normal_left2_1[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_1_normal_right2_1[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 168)  672         separable_conv_1_normal_left5_1[0
# __________________________________________________________________________________________________
# activation_296 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_298 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_300 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_302 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_304 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 28, 28, 168)  32424       activation_296[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 28, 28, 168)  29736       activation_298[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 28, 28, 168)  32424       activation_300[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 28, 28, 168)  29736       activation_302[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 28, 28, 168)  29736       activation_304[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 168)  672         separable_conv_2_normal_left1_1[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_2_normal_right1_1[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 168)  672         separable_conv_2_normal_left2_1[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_2_normal_right2_1[
# __________________________________________________________________________________________________
# normal_left3_1 (AveragePooling2 (None, 28, 28, 168)  0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# normal_left4_1 (AveragePooling2 (None, 28, 28, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# normal_right4_1 (AveragePooling (None, 28, 28, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 168)  672         separable_conv_2_normal_left5_1[0
# __________________________________________________________________________________________________
# normal_add_1_1 (Add)            (None, 28, 28, 168)  0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_1 (Add)            (None, 28, 28, 168)  0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_1 (Add)            (None, 28, 28, 168)  0           normal_left3_1[0][0]
#                                                                  adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# normal_add_4_1 (Add)            (None, 28, 28, 168)  0           normal_left4_1[0][0]
#                                                                  normal_right4_1[0][0]
# __________________________________________________________________________________________________
# normal_add_5_1 (Add)            (None, 28, 28, 168)  0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# normal_concat_1 (Concatenate)   (None, 28, 28, 1008) 0           adjust_bn_1[0][0]
#                                                                  normal_add_1_1[0][0]
#                                                                  normal_add_2_1[0][0]
#                                                                  normal_add_3_1[0][0]
#                                                                  normal_add_4_1[0][0]
#                                                                  normal_add_5_1[0][0]
# __________________________________________________________________________________________________
# activation_305 (Activation)     (None, 28, 28, 1008) 0           normal_concat_0[0][0]
# __________________________________________________________________________________________________
# activation_306 (Activation)     (None, 28, 28, 1008) 0           normal_concat_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_2 (Conv2 (None, 28, 28, 168)  169344      activation_305[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_2 (Conv2D)        (None, 28, 28, 168)  169344      activation_306[0][0]
# __________________________________________________________________________________________________
# adjust_bn_2 (BatchNormalization (None, 28, 28, 168)  672         adjust_conv_projection_2[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_2 (BatchNormalizati (None, 28, 28, 168)  672         normal_conv_1_2[0][0]
# __________________________________________________________________________________________________
# activation_307 (Activation)     (None, 28, 28, 168)  0           normal_bn_1_2[0][0]
# __________________________________________________________________________________________________
# activation_309 (Activation)     (None, 28, 28, 168)  0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_311 (Activation)     (None, 28, 28, 168)  0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_313 (Activation)     (None, 28, 28, 168)  0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_315 (Activation)     (None, 28, 28, 168)  0           normal_bn_1_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_2 (None, 28, 28, 168)  32424       activation_307[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 28, 28, 168)  29736       activation_309[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_2 (None, 28, 28, 168)  32424       activation_311[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 28, 28, 168)  29736       activation_313[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_2 (None, 28, 28, 168)  29736       activation_315[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 168)  672         separable_conv_1_normal_left1_2[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_1_normal_right1_2[
# ...
# __________________________________________________________________________________________________
# activation_504 (Activation)     (None, 7, 7, 672)    0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_506 (Activation)     (None, 7, 7, 672)    0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 7, 7, 672)    468384      activation_498[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 7, 7, 672)    457632      activation_500[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 7, 7, 672)    468384      activation_502[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 7, 7, 672)    457632      activation_504[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 7, 7, 672)    457632      activation_506[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_2_normal_left1_17[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 672)    2688        separable_conv_2_normal_right1_17
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_2_normal_left2_17[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 672)    2688        separable_conv_2_normal_right2_17
# __________________________________________________________________________________________________
# normal_left3_17 (AveragePooling (None, 7, 7, 672)    0           normal_bn_1_17[0][0]
# __________________________________________________________________________________________________
# normal_left4_17 (AveragePooling (None, 7, 7, 672)    0           adjust_bn_17[0][0]
# __________________________________________________________________________________________________
# normal_right4_17 (AveragePoolin (None, 7, 7, 672)    0           adjust_bn_17[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_2_normal_left5_17[
# __________________________________________________________________________________________________
# normal_add_1_17 (Add)           (None, 7, 7, 672)    0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_17 (Add)           (None, 7, 7, 672)    0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_17 (Add)           (None, 7, 7, 672)    0           normal_left3_17[0][0]
#                                                                  adjust_bn_17[0][0]
# __________________________________________________________________________________________________
# normal_add_4_17 (Add)           (None, 7, 7, 672)    0           normal_left4_17[0][0]
#                                                                  normal_right4_17[0][0]
# __________________________________________________________________________________________________
# normal_add_5_17 (Add)           (None, 7, 7, 672)    0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_17[0][0]
# __________________________________________________________________________________________________
# normal_concat_17 (Concatenate)  (None, 7, 7, 4032)   0           adjust_bn_17[0][0]
#                                                                  normal_add_1_17[0][0]
#                                                                  normal_add_2_17[0][0]
#                                                                  normal_add_3_17[0][0]
#                                                                  normal_add_4_17[0][0]
#                                                                  normal_add_5_17[0][0]
# __________________________________________________________________________________________________
# activation_507 (Activation)     (None, 7, 7, 4032)   0           normal_concat_16[0][0]
# __________________________________________________________________________________________________
# activation_508 (Activation)     (None, 7, 7, 4032)   0           normal_concat_17[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_18 (Conv (None, 7, 7, 672)    2709504     activation_507[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_18 (Conv2D)       (None, 7, 7, 672)    2709504     activation_508[0][0]
# __________________________________________________________________________________________________
# adjust_bn_18 (BatchNormalizatio (None, 7, 7, 672)    2688        adjust_conv_projection_18[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_18 (BatchNormalizat (None, 7, 7, 672)    2688        normal_conv_1_18[0][0]
# __________________________________________________________________________________________________
# activation_509 (Activation)     (None, 7, 7, 672)    0           normal_bn_1_18[0][0]
# __________________________________________________________________________________________________
# activation_511 (Activation)     (None, 7, 7, 672)    0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# activation_513 (Activation)     (None, 7, 7, 672)    0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# activation_515 (Activation)     (None, 7, 7, 672)    0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# activation_517 (Activation)     (None, 7, 7, 672)    0           normal_bn_1_18[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_1 (None, 7, 7, 672)    468384      activation_509[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 7, 7, 672)    457632      activation_511[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_1 (None, 7, 7, 672)    468384      activation_513[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 7, 7, 672)    457632      activation_515[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_1 (None, 7, 7, 672)    457632      activation_517[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_1_normal_left1_18[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 7, 7, 672)    2688        separable_conv_1_normal_right1_18
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_1_normal_left2_18[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 7, 7, 672)    2688        separable_conv_1_normal_right2_18
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_1_normal_left5_18[
# __________________________________________________________________________________________________
# activation_510 (Activation)     (None, 7, 7, 672)    0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_512 (Activation)     (None, 7, 7, 672)    0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_514 (Activation)     (None, 7, 7, 672)    0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_516 (Activation)     (None, 7, 7, 672)    0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_518 (Activation)     (None, 7, 7, 672)    0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 7, 7, 672)    468384      activation_510[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 7, 7, 672)    457632      activation_512[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 7, 7, 672)    468384      activation_514[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 7, 7, 672)    457632      activation_516[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 7, 7, 672)    457632      activation_518[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_2_normal_left1_18[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 672)    2688        separable_conv_2_normal_right1_18
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_2_normal_left2_18[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 672)    2688        separable_conv_2_normal_right2_18
# __________________________________________________________________________________________________
# normal_left3_18 (AveragePooling (None, 7, 7, 672)    0           normal_bn_1_18[0][0]
# __________________________________________________________________________________________________
# normal_left4_18 (AveragePooling (None, 7, 7, 672)    0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# normal_right4_18 (AveragePoolin (None, 7, 7, 672)    0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_2_normal_left5_18[
# __________________________________________________________________________________________________
# normal_add_1_18 (Add)           (None, 7, 7, 672)    0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_18 (Add)           (None, 7, 7, 672)    0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_18 (Add)           (None, 7, 7, 672)    0           normal_left3_18[0][0]
#                                                                  adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# normal_add_4_18 (Add)           (None, 7, 7, 672)    0           normal_left4_18[0][0]
#                                                                  normal_right4_18[0][0]
# __________________________________________________________________________________________________
# normal_add_5_18 (Add)           (None, 7, 7, 672)    0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_18[0][0]
# __________________________________________________________________________________________________
# normal_concat_18 (Concatenate)  (None, 7, 7, 4032)   0           adjust_bn_18[0][0]
#                                                                  normal_add_1_18[0][0]
#                                                                  normal_add_2_18[0][0]
#                                                                  normal_add_3_18[0][0]
#                                                                  normal_add_4_18[0][0]
#                                                                  normal_add_5_18[0][0]
# __________________________________________________________________________________________________
# activation_519 (Activation)     (None, 7, 7, 4032)   0           normal_concat_18[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 4032)         0           activation_519[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 1000)         4033000     global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 88,949,818
# Trainable params: 88,753,150
# Non-trainable params: 196,668
# __________________________________________________________________________________________________

# %%
last_layer = model.get_layer('normal_concat_18').output
x= Flatten(name='flatten')(last_layer)
x = Dense(128, activation='relu', name='fc1')(x)
x = Dense(64, activation='relu', name='fc2')(x)
out = Dense(4, activation='sigmoid', name='output')(x)  ##  4 classes [dog, cat, horse, human]
model = Model(img_input, out)

for layer in model.layers[:-3]:
	layer.trainable = False

model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# stem_conv1 (Conv2D)             (None, 111, 111, 96) 2592        input_4[0][0]
# __________________________________________________________________________________________________
# stem_bn1 (BatchNormalization)   (None, 111, 111, 96) 384         stem_conv1[0][0]
# __________________________________________________________________________________________________
# activation_260 (Activation)     (None, 111, 111, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_1 (Conv2D (None, 111, 111, 42) 4032        activation_260[0][0]
# __________________________________________________________________________________________________
# reduction_bn_1_stem_1 (BatchNor (None, 111, 111, 42) 168         reduction_conv_1_stem_1[0][0]
# __________________________________________________________________________________________________
# activation_261 (Activation)     (None, 111, 111, 42) 0           reduction_bn_1_stem_1[0][0]
# __________________________________________________________________________________________________
# activation_263 (Activation)     (None, 111, 111, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 115, 115, 42) 0           activation_261[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 117, 117, 96) 0           activation_263[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 56, 56, 42)   2814        separable_conv_1_pad_reduction_le
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 56, 56, 42)   8736        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 56, 56, 42)   168         separable_conv_1_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 56, 56, 42)   168         separable_conv_1_reduction_right1
# __________________________________________________________________________________________________
# activation_262 (Activation)     (None, 56, 56, 42)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# activation_264 (Activation)     (None, 56, 56, 42)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 56, 56, 42)   2814        activation_262[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 56, 56, 42)   3822        activation_264[0][0]
# __________________________________________________________________________________________________
# activation_265 (Activation)     (None, 111, 111, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 56, 56, 42)   168         separable_conv_2_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 56, 56, 42)   168         separable_conv_2_reduction_right1
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 117, 117, 96) 0           activation_265[0][0]
# __________________________________________________________________________________________________
# activation_267 (Activation)     (None, 111, 111, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_add_1_stem_1 (Add)    (None, 56, 56, 42)   0           separable_conv_2_bn_reduction_lef
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 56, 56, 42)   8736        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 115, 115, 96) 0           activation_267[0][0]
# __________________________________________________________________________________________________
# activation_269 (Activation)     (None, 56, 56, 42)   0           reduction_add_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 56, 56, 42)   168         separable_conv_1_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 56, 56, 42)   6432        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 56, 56, 42)   2142        activation_269[0][0]
# __________________________________________________________________________________________________
# activation_266 (Activation)     (None, 56, 56, 42)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 56, 56, 42)   168         separable_conv_1_reduction_right3
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 56, 56, 42)   168         separable_conv_1_reduction_left4_
# __________________________________________________________________________________________________
# reduction_pad_1_stem_1 (ZeroPad (None, 113, 113, 42) 0           reduction_bn_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 56, 56, 42)   3822        activation_266[0][0]
# __________________________________________________________________________________________________
# activation_268 (Activation)     (None, 56, 56, 42)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# activation_270 (Activation)     (None, 56, 56, 42)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# reduction_left2_stem_1 (MaxPool (None, 56, 56, 42)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 56, 56, 42)   168         separable_conv_2_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 56, 56, 42)   2814        activation_268[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 56, 56, 42)   2142        activation_270[0][0]
# __________________________________________________________________________________________________
# adjust_relu_1_stem_2 (Activatio (None, 111, 111, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_add_2_stem_1 (Add)    (None, 56, 56, 42)   0           reduction_left2_stem_1[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# reduction_left3_stem_1 (Average (None, 56, 56, 42)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 56, 56, 42)   168         separable_conv_2_reduction_right3
# __________________________________________________________________________________________________
# reduction_left4_stem_1 (Average (None, 56, 56, 42)   0           reduction_add_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 56, 56, 42)   168         separable_conv_2_reduction_left4_
# __________________________________________________________________________________________________
# reduction_right5_stem_1 (MaxPoo (None, 56, 56, 42)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 112, 112, 96) 0           adjust_relu_1_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add3_stem_1 (Add)     (None, 56, 56, 42)   0           reduction_left3_stem_1[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 56, 56, 42)   0           reduction_add_2_stem_1[0][0]
#                                                                  reduction_left4_stem_1[0][0]
# __________________________________________________________________________________________________
# reduction_add4_stem_1 (Add)     (None, 56, 56, 42)   0           separable_conv_2_bn_reduction_lef
#                                                                  reduction_right5_stem_1[0][0]
# __________________________________________________________________________________________________
# cropping2d_4 (Cropping2D)       (None, 111, 111, 96) 0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# reduction_concat_stem_1 (Concat (None, 56, 56, 168)  0           reduction_add_2_stem_1[0][0]
#                                                                  reduction_add3_stem_1[0][0]
#                                                                  add_4[0][0]
#                                                                  reduction_add4_stem_1[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_1_stem_2 (Avera (None, 56, 56, 96)   0           adjust_relu_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_2_stem_2 (Avera (None, 56, 56, 96)   0           cropping2d_4[0][0]
# __________________________________________________________________________________________________
# activation_271 (Activation)     (None, 56, 56, 168)  0           reduction_concat_stem_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_1_stem_2 (Conv2D)   (None, 56, 56, 42)   4032        adjust_avg_pool_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_conv_2_stem_2 (Conv2D)   (None, 56, 56, 42)   4032        adjust_avg_pool_2_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_2 (Conv2D (None, 56, 56, 84)   14112       activation_271[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 56, 56, 84)   0           adjust_conv_1_stem_2[0][0]
#                                                                  adjust_conv_2_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_bn_1_stem_2 (BatchNor (None, 56, 56, 84)   336         reduction_conv_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_bn_stem_2 (BatchNormaliz (None, 56, 56, 84)   336         concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_272 (Activation)     (None, 56, 56, 84)   0           reduction_bn_1_stem_2[0][0]
# __________________________________________________________________________________________________
# activation_274 (Activation)     (None, 56, 56, 84)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 59, 59, 84)   0           activation_272[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 61, 61, 84)   0           activation_274[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 28, 28, 84)   9156        separable_conv_1_pad_reduction_le
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 28, 28, 84)   11172       separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 28, 28, 84)   336         separable_conv_1_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 28, 28, 84)   336         separable_conv_1_reduction_right1
# __________________________________________________________________________________________________
# activation_273 (Activation)     (None, 28, 28, 84)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# activation_275 (Activation)     (None, 28, 28, 84)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 28, 28, 84)   9156        activation_273[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 28, 28, 84)   11172       activation_275[0][0]
# __________________________________________________________________________________________________
# activation_276 (Activation)     (None, 56, 56, 84)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 28, 28, 84)   336         separable_conv_2_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 28, 28, 84)   336         separable_conv_2_reduction_right1
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 61, 61, 84)   0           activation_276[0][0]
# __________________________________________________________________________________________________
# activation_278 (Activation)     (None, 56, 56, 84)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add_1_stem_2 (Add)    (None, 28, 28, 84)   0           separable_conv_2_bn_reduction_lef
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 28, 28, 84)   11172       separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 59, 59, 84)   0           activation_278[0][0]
# __________________________________________________________________________________________________
# activation_280 (Activation)     (None, 28, 28, 84)   0           reduction_add_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 28, 28, 84)   336         separable_conv_1_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 28, 28, 84)   9156        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 28, 28, 84)   7812        activation_280[0][0]
# __________________________________________________________________________________________________
# activation_277 (Activation)     (None, 28, 28, 84)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 28, 28, 84)   336         separable_conv_1_reduction_right3
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 28, 28, 84)   336         separable_conv_1_reduction_left4_
# __________________________________________________________________________________________________
# reduction_pad_1_stem_2 (ZeroPad (None, 57, 57, 84)   0           reduction_bn_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 28, 28, 84)   11172       activation_277[0][0]
# __________________________________________________________________________________________________
# activation_279 (Activation)     (None, 28, 28, 84)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# activation_281 (Activation)     (None, 28, 28, 84)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# reduction_left2_stem_2 (MaxPool (None, 28, 28, 84)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 28, 28, 84)   336         separable_conv_2_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 28, 28, 84)   9156        activation_279[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 28, 28, 84)   7812        activation_281[0][0]
# __________________________________________________________________________________________________
# adjust_relu_1_0 (Activation)    (None, 56, 56, 168)  0           reduction_concat_stem_1[0][0]
# __________________________________________________________________________________________________
# reduction_add_2_stem_2 (Add)    (None, 28, 28, 84)   0           reduction_left2_stem_2[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# reduction_left3_stem_2 (Average (None, 28, 28, 84)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 28, 28, 84)   336         separable_conv_2_reduction_right3
# __________________________________________________________________________________________________
# reduction_left4_stem_2 (Average (None, 28, 28, 84)   0           reduction_add_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 28, 28, 84)   336         separable_conv_2_reduction_left4_
# __________________________________________________________________________________________________
# reduction_right5_stem_2 (MaxPoo (None, 28, 28, 84)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 57, 57, 168)  0           adjust_relu_1_0[0][0]
# __________________________________________________________________________________________________
# reduction_add3_stem_2 (Add)     (None, 28, 28, 84)   0           reduction_left3_stem_2[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 28, 28, 84)   0           reduction_add_2_stem_2[0][0]
#                                                                  reduction_left4_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add4_stem_2 (Add)     (None, 28, 28, 84)   0           separable_conv_2_bn_reduction_lef
#                                                                  reduction_right5_stem_2[0][0]
# __________________________________________________________________________________________________
# cropping2d_5 (Cropping2D)       (None, 56, 56, 168)  0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# reduction_concat_stem_2 (Concat (None, 28, 28, 336)  0           reduction_add_2_stem_2[0][0]
#                                                                  reduction_add3_stem_2[0][0]
#                                                                  add_5[0][0]
#                                                                  reduction_add4_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_1_0 (AveragePoo (None, 28, 28, 168)  0           adjust_relu_1_0[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_2_0 (AveragePoo (None, 28, 28, 168)  0           cropping2d_5[0][0]
# __________________________________________________________________________________________________
# adjust_conv_1_0 (Conv2D)        (None, 28, 28, 84)   14112       adjust_avg_pool_1_0[0][0]
# __________________________________________________________________________________________________
# adjust_conv_2_0 (Conv2D)        (None, 28, 28, 84)   14112       adjust_avg_pool_2_0[0][0]
# __________________________________________________________________________________________________
# activation_282 (Activation)     (None, 28, 28, 336)  0           reduction_concat_stem_2[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 28, 28, 168)  0           adjust_conv_1_0[0][0]
#                                                                  adjust_conv_2_0[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_0 (Conv2D)        (None, 28, 28, 168)  56448       activation_282[0][0]
# __________________________________________________________________________________________________
# adjust_bn_0 (BatchNormalization (None, 28, 28, 168)  672         concatenate_5[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_0 (BatchNormalizati (None, 28, 28, 168)  672         normal_conv_1_0[0][0]
# __________________________________________________________________________________________________
# activation_283 (Activation)     (None, 28, 28, 168)  0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# activation_285 (Activation)     (None, 28, 28, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_287 (Activation)     (None, 28, 28, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_289 (Activation)     (None, 28, 28, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_291 (Activation)     (None, 28, 28, 168)  0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_0 (None, 28, 28, 168)  32424       activation_283[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 28, 28, 168)  29736       activation_285[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_0 (None, 28, 28, 168)  32424       activation_287[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 28, 28, 168)  29736       activation_289[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_0 (None, 28, 28, 168)  29736       activation_291[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 168)  672         separable_conv_1_normal_left1_0[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_1_normal_right1_0[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 168)  672         separable_conv_1_normal_left2_0[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_1_normal_right2_0[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 168)  672         separable_conv_1_normal_left5_0[0
# __________________________________________________________________________________________________
# activation_284 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_286 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_288 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_290 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_292 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_0 (None, 28, 28, 168)  32424       activation_284[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 28, 28, 168)  29736       activation_286[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_0 (None, 28, 28, 168)  32424       activation_288[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 28, 28, 168)  29736       activation_290[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_0 (None, 28, 28, 168)  29736       activation_292[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 168)  672         separable_conv_2_normal_left1_0[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_2_normal_right1_0[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 168)  672         separable_conv_2_normal_left2_0[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_2_normal_right2_0[
# __________________________________________________________________________________________________
# normal_left3_0 (AveragePooling2 (None, 28, 28, 168)  0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# normal_left4_0 (AveragePooling2 (None, 28, 28, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# normal_right4_0 (AveragePooling (None, 28, 28, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 168)  672         separable_conv_2_normal_left5_0[0
# __________________________________________________________________________________________________
# normal_add_1_0 (Add)            (None, 28, 28, 168)  0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_0 (Add)            (None, 28, 28, 168)  0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_0 (Add)            (None, 28, 28, 168)  0           normal_left3_0[0][0]
#                                                                  adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# normal_add_4_0 (Add)            (None, 28, 28, 168)  0           normal_left4_0[0][0]
#                                                                  normal_right4_0[0][0]
# __________________________________________________________________________________________________
# normal_add_5_0 (Add)            (None, 28, 28, 168)  0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# normal_concat_0 (Concatenate)   (None, 28, 28, 1008) 0           adjust_bn_0[0][0]
#                                                                  normal_add_1_0[0][0]
#                                                                  normal_add_2_0[0][0]
#                                                                  normal_add_3_0[0][0]
#                                                                  normal_add_4_0[0][0]
#                                                                  normal_add_5_0[0][0]
# __________________________________________________________________________________________________
# activation_293 (Activation)     (None, 28, 28, 336)  0           reduction_concat_stem_2[0][0]
# __________________________________________________________________________________________________
# activation_294 (Activation)     (None, 28, 28, 1008) 0           normal_concat_0[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_1 (Conv2 (None, 28, 28, 168)  56448       activation_293[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_1 (Conv2D)        (None, 28, 28, 168)  169344      activation_294[0][0]
# __________________________________________________________________________________________________
# adjust_bn_1 (BatchNormalization (None, 28, 28, 168)  672         adjust_conv_projection_1[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_1 (BatchNormalizati (None, 28, 28, 168)  672         normal_conv_1_1[0][0]
# __________________________________________________________________________________________________
# activation_295 (Activation)     (None, 28, 28, 168)  0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# activation_297 (Activation)     (None, 28, 28, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_299 (Activation)     (None, 28, 28, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_301 (Activation)     (None, 28, 28, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_303 (Activation)     (None, 28, 28, 168)  0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_1 (None, 28, 28, 168)  32424       activation_295[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 28, 28, 168)  29736       activation_297[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_1 (None, 28, 28, 168)  32424       activation_299[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 28, 28, 168)  29736       activation_301[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_1 (None, 28, 28, 168)  29736       activation_303[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 168)  672         separable_conv_1_normal_left1_1[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_1_normal_right1_1[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 168)  672         separable_conv_1_normal_left2_1[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_1_normal_right2_1[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 168)  672         separable_conv_1_normal_left5_1[0
# __________________________________________________________________________________________________
# activation_296 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_298 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_300 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_302 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_304 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 28, 28, 168)  32424       activation_296[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 28, 28, 168)  29736       activation_298[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 28, 28, 168)  32424       activation_300[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 28, 28, 168)  29736       activation_302[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 28, 28, 168)  29736       activation_304[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 168)  672         separable_conv_2_normal_left1_1[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_2_normal_right1_1[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 168)  672         separable_conv_2_normal_left2_1[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_2_normal_right2_1[
# __________________________________________________________________________________________________
# normal_left3_1 (AveragePooling2 (None, 28, 28, 168)  0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# normal_left4_1 (AveragePooling2 (None, 28, 28, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# normal_right4_1 (AveragePooling (None, 28, 28, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 168)  672         separable_conv_2_normal_left5_1[0
# __________________________________________________________________________________________________
# normal_add_1_1 (Add)            (None, 28, 28, 168)  0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_1 (Add)            (None, 28, 28, 168)  0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_1 (Add)            (None, 28, 28, 168)  0           normal_left3_1[0][0]
#                                                                  adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# normal_add_4_1 (Add)            (None, 28, 28, 168)  0           normal_left4_1[0][0]
#                                                                  normal_right4_1[0][0]
# __________________________________________________________________________________________________
# normal_add_5_1 (Add)            (None, 28, 28, 168)  0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# normal_concat_1 (Concatenate)   (None, 28, 28, 1008) 0           adjust_bn_1[0][0]
#                                                                  normal_add_1_1[0][0]
#                                                                  normal_add_2_1[0][0]
#                                                                  normal_add_3_1[0][0]
#                                                                  normal_add_4_1[0][0]
#                                                                  normal_add_5_1[0][0]
# __________________________________________________________________________________________________
# activation_305 (Activation)     (None, 28, 28, 1008) 0           normal_concat_0[0][0]
# __________________________________________________________________________________________________
# activation_306 (Activation)     (None, 28, 28, 1008) 0           normal_concat_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_2 (Conv2 (None, 28, 28, 168)  169344      activation_305[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_2 (Conv2D)        (None, 28, 28, 168)  169344      activation_306[0][0]
# __________________________________________________________________________________________________
# adjust_bn_2 (BatchNormalization (None, 28, 28, 168)  672         adjust_conv_projection_2[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_2 (BatchNormalizati (None, 28, 28, 168)  672         normal_conv_1_2[0][0]
# __________________________________________________________________________________________________
# activation_307 (Activation)     (None, 28, 28, 168)  0           normal_bn_1_2[0][0]
# __________________________________________________________________________________________________
# activation_309 (Activation)     (None, 28, 28, 168)  0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_311 (Activation)     (None, 28, 28, 168)  0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_313 (Activation)     (None, 28, 28, 168)  0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_315 (Activation)     (None, 28, 28, 168)  0           normal_bn_1_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_2 (None, 28, 28, 168)  32424       activation_307[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 28, 28, 168)  29736       activation_309[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_2 (None, 28, 28, 168)  32424       activation_311[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 28, 28, 168)  29736       activation_313[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_2 (None, 28, 28, 168)  29736       activation_315[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 168)  672         separable_conv_1_normal_left1_2[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_1_normal_right1_2[
# ...
# __________________________________________________________________________________________________
# activation_506 (Activation)     (None, 7, 7, 672)    0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 7, 7, 672)    468384      activation_498[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 7, 7, 672)    457632      activation_500[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 7, 7, 672)    468384      activation_502[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 7, 7, 672)    457632      activation_504[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 7, 7, 672)    457632      activation_506[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_2_normal_left1_17[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 672)    2688        separable_conv_2_normal_right1_17
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_2_normal_left2_17[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 672)    2688        separable_conv_2_normal_right2_17
# __________________________________________________________________________________________________
# normal_left3_17 (AveragePooling (None, 7, 7, 672)    0           normal_bn_1_17[0][0]
# __________________________________________________________________________________________________
# normal_left4_17 (AveragePooling (None, 7, 7, 672)    0           adjust_bn_17[0][0]
# __________________________________________________________________________________________________
# normal_right4_17 (AveragePoolin (None, 7, 7, 672)    0           adjust_bn_17[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_2_normal_left5_17[
# __________________________________________________________________________________________________
# normal_add_1_17 (Add)           (None, 7, 7, 672)    0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_17 (Add)           (None, 7, 7, 672)    0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_17 (Add)           (None, 7, 7, 672)    0           normal_left3_17[0][0]
#                                                                  adjust_bn_17[0][0]
# __________________________________________________________________________________________________
# normal_add_4_17 (Add)           (None, 7, 7, 672)    0           normal_left4_17[0][0]
#                                                                  normal_right4_17[0][0]
# __________________________________________________________________________________________________
# normal_add_5_17 (Add)           (None, 7, 7, 672)    0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_17[0][0]
# __________________________________________________________________________________________________
# normal_concat_17 (Concatenate)  (None, 7, 7, 4032)   0           adjust_bn_17[0][0]
#                                                                  normal_add_1_17[0][0]
#                                                                  normal_add_2_17[0][0]
#                                                                  normal_add_3_17[0][0]
#                                                                  normal_add_4_17[0][0]
#                                                                  normal_add_5_17[0][0]
# __________________________________________________________________________________________________
# activation_507 (Activation)     (None, 7, 7, 4032)   0           normal_concat_16[0][0]
# __________________________________________________________________________________________________
# activation_508 (Activation)     (None, 7, 7, 4032)   0           normal_concat_17[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_18 (Conv (None, 7, 7, 672)    2709504     activation_507[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_18 (Conv2D)       (None, 7, 7, 672)    2709504     activation_508[0][0]
# __________________________________________________________________________________________________
# adjust_bn_18 (BatchNormalizatio (None, 7, 7, 672)    2688        adjust_conv_projection_18[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_18 (BatchNormalizat (None, 7, 7, 672)    2688        normal_conv_1_18[0][0]
# __________________________________________________________________________________________________
# activation_509 (Activation)     (None, 7, 7, 672)    0           normal_bn_1_18[0][0]
# __________________________________________________________________________________________________
# activation_511 (Activation)     (None, 7, 7, 672)    0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# activation_513 (Activation)     (None, 7, 7, 672)    0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# activation_515 (Activation)     (None, 7, 7, 672)    0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# activation_517 (Activation)     (None, 7, 7, 672)    0           normal_bn_1_18[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_1 (None, 7, 7, 672)    468384      activation_509[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 7, 7, 672)    457632      activation_511[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_1 (None, 7, 7, 672)    468384      activation_513[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 7, 7, 672)    457632      activation_515[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_1 (None, 7, 7, 672)    457632      activation_517[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_1_normal_left1_18[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 7, 7, 672)    2688        separable_conv_1_normal_right1_18
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_1_normal_left2_18[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 7, 7, 672)    2688        separable_conv_1_normal_right2_18
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_1_normal_left5_18[
# __________________________________________________________________________________________________
# activation_510 (Activation)     (None, 7, 7, 672)    0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_512 (Activation)     (None, 7, 7, 672)    0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_514 (Activation)     (None, 7, 7, 672)    0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_516 (Activation)     (None, 7, 7, 672)    0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_518 (Activation)     (None, 7, 7, 672)    0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 7, 7, 672)    468384      activation_510[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 7, 7, 672)    457632      activation_512[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 7, 7, 672)    468384      activation_514[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 7, 7, 672)    457632      activation_516[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 7, 7, 672)    457632      activation_518[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_2_normal_left1_18[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 672)    2688        separable_conv_2_normal_right1_18
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_2_normal_left2_18[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 672)    2688        separable_conv_2_normal_right2_18
# __________________________________________________________________________________________________
# normal_left3_18 (AveragePooling (None, 7, 7, 672)    0           normal_bn_1_18[0][0]
# __________________________________________________________________________________________________
# normal_left4_18 (AveragePooling (None, 7, 7, 672)    0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# normal_right4_18 (AveragePoolin (None, 7, 7, 672)    0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_2_normal_left5_18[
# __________________________________________________________________________________________________
# normal_add_1_18 (Add)           (None, 7, 7, 672)    0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_18 (Add)           (None, 7, 7, 672)    0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_18 (Add)           (None, 7, 7, 672)    0           normal_left3_18[0][0]
#                                                                  adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# normal_add_4_18 (Add)           (None, 7, 7, 672)    0           normal_left4_18[0][0]
#                                                                  normal_right4_18[0][0]
# __________________________________________________________________________________________________
# normal_add_5_18 (Add)           (None, 7, 7, 672)    0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_18[0][0]
# __________________________________________________________________________________________________
# normal_concat_18 (Concatenate)  (None, 7, 7, 4032)   0           adjust_bn_18[0][0]
#                                                                  normal_add_1_18[0][0]
#                                                                  normal_add_2_18[0][0]
#                                                                  normal_add_3_18[0][0]
#                                                                  normal_add_4_18[0][0]
#                                                                  normal_add_5_18[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 197568)       0           normal_concat_18[0][0]
# __________________________________________________________________________________________________
# fc1 (Dense)                     (None, 128)          25288832    flatten[0][0]
# __________________________________________________________________________________________________
# fc2 (Dense)                     (None, 64)           8256        fc1[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 4)            260         fc2[0][0]
# ==================================================================================================
# Total params: 110,214,166
# Trainable params: 25,297,348
# Non-trainable params: 84,916,818
# __________________________________________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['acc'])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
my_callbacks = [
    EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True),
    ModelCheckpoint(filepath='vgg16_model.h5', save_best_only=True),
]

# %%
history = model.fit(train_X, train_y,
                              batch_size=20,
                              epochs=20, 
                              validation_data=(val_X, val_y),
                              callbacks=my_callbacks)
# Out:
# Epoch 1/20
# 20/20 [==============================] - 8s 397ms/step - loss: 1.3772 - acc: 0.9900 - val_loss: 26.6181 - val_acc: 0.8725
# Epoch 2/20
# 20/20 [==============================] - 8s 400ms/step - loss: 6.2188 - acc: 0.9525 - val_loss: 11.3364 - val_acc: 0.9363
# Epoch 3/20
# 20/20 [==============================] - 8s 405ms/step - loss: 4.9419 - acc: 0.9800 - val_loss: 7.2741 - val_acc: 0.9657
# Epoch 4/20
# 20/20 [==============================] - 8s 410ms/step - loss: 0.7079 - acc: 0.9875 - val_loss: 7.3770 - val_acc: 0.9657
# Epoch 5/20
# 20/20 [==============================] - 8s 414ms/step - loss: 7.2016 - acc: 0.9550 - val_loss: 6.9658 - val_acc: 0.9706
# Epoch 6/20
# 20/20 [==============================] - 8s 411ms/step - loss: 5.4673 - acc: 0.9800 - val_loss: 10.4294 - val_acc: 0.9755
# Epoch 7/20
# 20/20 [==============================] - 8s 406ms/step - loss: 0.0117 - acc: 0.9950 - val_loss: 3.7150 - val_acc: 0.9755
# Epoch 8/20
# 20/20 [==============================] - 8s 402ms/step - loss: 0.6060 - acc: 0.9975 - val_loss: 4.6860 - val_acc: 0.9853
# Epoch 9/20
# 20/20 [==============================] - 8s 399ms/step - loss: 0.0000e+00 - acc: 1.0000 - val_loss: 3.8802 - val_acc: 0.9706
# Epoch 10/20
# 20/20 [==============================] - 8s 397ms/step - loss: 0.0000e+00 - acc: 1.0000 - val_loss: 4.4306 - val_acc: 0.9706
# Epoch 11/20
# 20/20 [==============================] - 8s 398ms/step - loss: 0.0000e+00 - acc: 1.0000 - val_loss: 4.4952 - val_acc: 0.9706
# Epoch 12/20
# 20/20 [==============================] - 8s 399ms/step - loss: 0.0000e+00 - acc: 1.0000 - val_loss: 4.5033 - val_acc: 0.9706

# %% [markdown]
# ## Visualize the results produced by the fine-tuned model
#
# - The accuracy significantly improved after fine-tuning producing validation sets results over 90% accuracy rate

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
from sklearn.metrics import accuracy_score

## Test Accuracy
predictions = model.predict(test_X)
ypred = predictions > 0.5

# Modify the data shape
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown='ignore')
mod_test_y = enc.fit_transform(test_y.reshape(-1, 1))
test_acc = accuracy_score(mod_test_y, ypred)

from sklearn.metrics import precision_recall_fscore_support, roc_auc_score

precision, recall, f1score, _ = precision_recall_fscore_support(mod_test_y, ypred)

#auc = roc_auc_score(mod_test_y, ypred)

print("Train Accuracy:\t", acc[-1])
print("Val Accuracy:\t", val_acc[-1])
print("Test Accuracy:\t", test_acc)
print("Precision:\t", precision)
print("Recall:\t\t", recall)
print("F1 Score:\t", f1score)
#print("AUC:\t\t", auc)
# Out:
# Train Accuracy:	 1.0
# Val Accuracy:	 0.970588207244873
# Test Accuracy:	 0.9068627450980392
# Precision:	 [0.92592593 0.96153846 0.90909091 0.9787234 ]
# Recall:		 [0.98039216 0.98039216 0.98039216 0.90196078]
# F1 Score:	 [0.95238095 0.97087379 0.94339623 0.93877551]
